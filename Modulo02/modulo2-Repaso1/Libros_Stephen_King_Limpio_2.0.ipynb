# %%
# Importa la biblioteca pandas 
import pandas as pd
# Importa la biblioteca requests 
import requests

# Configura pandas para que muestre todas las columnas
pd.set_option('display.max_columns', None)

# ENDPOINT para obtener libros de Stephen King
url = "https://api.nytimes.com/svc/books/v3/reviews.json?author=Stephen+King&api-key=YOUR_API_KEY"

# Realiza una solicitud a la URL
response = requests.get(url)
# Comprueba si la respuesta es exitosa
if response.status_code == 200:
    # Convierte la respuesta a JSON 
    json_response = response.json()

    # Define una función para limpiar los datos JSON y convertirlos en un DataFrame 
    def limpiar_json(datos_json):
        # Crea una lista vacía para almacenar los datos 
        libros = []
        # Crea un conjunto vacío para registrar los ISBN únicos y evitar duplicados
        isbn_list = set()

        # Itera sobre cada iterable en la sección 'results' 
        for item in datos_json['results']:
            # Intenta obtener el campo 'isbn13' de los datos del libro
            # Si es una lista, obtiene el primer elemento; si no, usa el valor tal cual
            # Si 'isbn13' no está presente o es None, usa 'Desconocido'
            isbn = item.get('isbn13')
            isbn = isbn[0] if isinstance(isbn, list) and isbn else 'Desconocido'

            # Si el ISBN no está duplicado
            if isbn not in isbn_list:
                # Obtiene el título del libro, el autor y la fecha de publicación del libro
                # Utiliza valores predeterminados en caso de que no estén 
                titulo = item.get('book_title', 'Desconocido')
                autor = item.get('book_author', 'Desconocido')
                fecha = item.get('publication_dt', 'Desconocido')

                # Agrega un diccionario con los datos del libro a la lista de libros
                libros.append({
                    'Título': titulo,
                    'Autor/a': autor,
                    'ID': isbn,
                    'Fecha': fecha,
                })
                # Añade el ISBN al conjunto para evitar futuros duplicados
                isbn_list.add(isbn)

        # Crea un DataFrame de pandas a partir de la lista de datos de los libros
        return pd.DataFrame(libros)

    # Llama a la función 'limpiar_json' 
    # Asigna el DataFrame resultante a una variable 
    df_libros = limpiar_json(json_response)

    # Imprime el DataFrame para ver los resultados
    print(df_libros)

    # Guarda el DataFrame en un archivo CSV 
    # Establece 'index=False' para no incluir la columna de índices en el archivo
    df_libros.to_csv("Libros_de_Stephen_King.csv", index=False)

# Si la solicitud no fue exitosa, imprime un mensaje de error con el código de estado de la petición
else:
    print(f"No ha funcionado, error tipo {response.status_code}")
# Out:
#                                         Título       Autor/a             ID  \
# 0                                     11/22/63  Stephen King  9780307951434
# 1                          Wolves of the Calla  Stephen King  9781848941137
# 2                   Nightmares and Dreamscapes  Stephen King  9781441615299
# 3                                  Black House  Stephen King  9780375504396
# 4                                    The Stand  Stephen King  9781848940833
# 5                           Four Past Midnight  Stephen King  9780816151776
# 6                               Needful Things  Stephen King  9781598877427
# 7                                Gerald's Game  Stephen King  9780670846504
# 8        Everything's Eventual : 14 Dark Tales  Stephen King  9781439568200
# 9                                           It  Stephen King  9780451169518
# 10                         Full Dark, No Stars  Stephen King  9781439192566
# 11                                Bag of Bones  Stephen King  9780671026073
# 12       Everything's Eventual : 14 Dark Tales  Stephen King  9781416537816
# 13                                 Rose Madder  Stephen King  9781568952611
# 14                                Doctor Sleep  Stephen King  9781451698855
# 15                                     Joyland  Stephen King  9781781162644
# 16                              Under the Dome  Stephen King  9781476735474
# 17                                     Revival  Stephen King  9781410473837
# 18                               Lisey's Story  Stephen King  9781416523352
# 19                           Just After Sunset  Stephen King  9781416586654
# 20                                    Duma Key  Stephen King  9781416552963
# 21                                Mr. Mercedes  Stephen King  9781410469007
# 22                Stephen King's Danse Macabre  Stephen King  9780896960763
# 23                                        Cujo  Stephen King  9780670451937
# 24                           Different Seasons  Stephen King  9780670272662
# 25                                   Christine  Stephen King  9780670220267
# 26                                Pet Sematary  Stephen King  9780385182447
# 27                               Skeleton Crew  Stephen King    Desconocido
# 28                                      Misery  Stephen King  9780670813643
# 29                           The Tommyknockers  Stephen King  9780399133145
# 30    The Waste Lands: The Dark Tower Book III  Stephen King  9780452267404
# 31  Needful Things: The Last Castle Rock Story  Stephen King  9780670839537
# 32           Insomnia,Stephen King Library Ed.  Stephen King  9780670855032
# 33                                 Rose Madder  Stephen King  9780670858699
# 34                                Bag of Bones  Stephen King  9780684853505
# 35     The Girl Who Loved Tom Gordon : A Novel  Stephen King  9780684867625
# 36          On Writing:  a Memoir of the Craft  Stephen King  9780606222549
# 37                                Dreamcatcher  Stephen King  9780743211383
# 38                              From a Buick 8  Stephen King  9780743211376
# 39                           The Dark Tower VI  Stephen King  9781880418598
# 40                                        Cell  Stephen King  9780743292337
# 41                             Finders Keepers  Stephen King  9781410479501
# 42                                End of Watch  Stephen King  9781410489906
# 43                                The Outsider  Stephen King  9781501180989
# 44                                   Elevation  Stephen King  9781982102319
# 45                               The Institute  Stephen King  9781982110567
#
#          Fecha
# 0   2011-11-13
# 1   2004-01-04
# 2   1993-10-24
# 3   2001-11-04
# 4   1990-05-13
# 5   1990-09-02
# 6   1991-10-20
# 7   1992-06-29
# 8   2002-04-14
# 9   1986-08-21
# 10  2010-11-28
# 11  1998-09-27
# 12  2002-03-18
# 13  1995-07-02
# 14  2013-09-16
# 15  2013-06-23
# 16  2009-11-08
# 17  2014-11-14
# 18  2006-11-12
# 19  2008-11-05
# 20  2008-01-21
# 21  2014-06-08
# 22  1981-05-10
# 23  1981-08-14
# 24  1982-08-11
# 25  1983-04-03
# 26  1983-10-21
# 27  1985-06-09
# 28  1987-05-31
# 29  1987-11-05
# 30  1991-09-29
# 31  1991-10-03
# 32  1994-10-06
# 33  1995-06-26
# 34  1998-09-21
# 35  1999-04-15
# 36  2000-10-05
# 37  2001-03-15
# 38  2002-09-23
# 39  2004-06-20
# 40  2006-01-23
# 41  2015-05-31
# 42  2016-06-12
# 43  2018-05-22
# 44  2018-10-26
# 45  2019-09-08
